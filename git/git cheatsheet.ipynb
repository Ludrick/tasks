# %% [markdown]
# <img src="imgs/img0.png" width="1000">
#
# ___
# <br><br>

# %% [markdown]
# <img src="imgs/img1.png" width="1000">
#
# <br><br>

# %% [markdown]
# <img src="imgs/img2.png" width="1000">
